# %%
import pandas as pd

# %%
dataframe1 = pd.read_csv("Datasets/file1.csv")

# %%
print(dataframe1)
# Out:
#        Nome  Età Sesso                Corso
# 0  Giovanni   28     m        Cybersecurity
# 1     Magda   27     f             Big Data
# 2     Elena   39     f        Cybersecurity
# 3   Michele   32     m          Scenografia
# 4      Anna   41     f  Facebook 4 Business
# 5      Aldo   19     m        Cybersecurity
# 6   Antonio   53     m             Big Data
# 7    Monica   24     f  Facebook 4 Business

# %%
type(dataframe1)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("Datasets/file1.csv", header=0)
# Out:
#        Nome  Età Sesso                Corso
# 0  Giovanni   28     m        Cybersecurity
# 1     Magda   27     f             Big Data
# 2     Elena   39     f        Cybersecurity
# 3   Michele   32     m          Scenografia
# 4      Anna   41     f  Facebook 4 Business
# 5      Aldo   19     m        Cybersecurity
# 6   Antonio   53     m             Big Data
# 7    Monica   24     f  Facebook 4 Business

# %%
pd.read_csv("Datasets/file1.csv", header = 0, names=["var1", "var2", "var3", "var4"])  # dare direttamente i nomi ai campi
# Out:
#        var1  var2 var3                 var4
# 0  Giovanni    28    m        Cybersecurity
# 1     Magda    27    f             Big Data
# 2     Elena    39    f        Cybersecurity
# 3   Michele    32    m          Scenografia
# 4      Anna    41    f  Facebook 4 Business
# 5      Aldo    19    m        Cybersecurity
# 6   Antonio    53    m             Big Data
# 7    Monica    24    f  Facebook 4 Business

# %%
pd.read_csv("Datasets/file1.csv", usecols=["Nome", "Sesso"])  # selezionare solo alcune colonne
# Out:
#        Nome Sesso
# 0  Giovanni     m
# 1     Magda     f
# 2     Elena     f
# 3   Michele     m
# 4      Anna     f
# 5      Aldo     m
# 6   Antonio     m
# 7    Monica     f

# %%
pd.read_csv("Datasets/file1.csv", usecols=[0, 1, 2])  # selezionare solo alcune colonne
# Out:
#        Nome  Età Sesso
# 0  Giovanni   28     m
# 1     Magda   27     f
# 2     Elena   39     f
# 3   Michele   32     m
# 4      Anna   41     f
# 5      Aldo   19     m
# 6   Antonio   53     m
# 7    Monica   24     f

# %%
dataframe1.head()
# Out:
#        Nome  Età Sesso                Corso
# 0  Giovanni   28     m        Cybersecurity
# 1     Magda   27     f             Big Data
# 2     Elena   39     f        Cybersecurity
# 3   Michele   32     m          Scenografia
# 4      Anna   41     f  Facebook 4 Business

# %%
dataframe1.head(2)
# Out:
#        Nome  Età Sesso          Corso
# 0  Giovanni   28     m  Cybersecurity
# 1     Magda   27     f       Big Data

# %%
dataframe1.columns
# Out:
# Index(['Nome', 'Età', 'Sesso', 'Corso'], dtype='object')

# %%
dataframe1.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
dataframe1.values
# Out:
# array([['Giovanni', 28, 'm', 'Cybersecurity'],
#        ['Magda', 27, 'f', 'Big Data'],
#        ['Elena', 39, 'f', 'Cybersecurity'],
#        ['Michele', 32, 'm', 'Scenografia'],
#        ['Anna', 41, 'f', 'Facebook 4 Business'],
#        ['Aldo', 19, 'm', 'Cybersecurity'],
#        ['Antonio', 53, 'm', 'Big Data'],
#        ['Monica', 24, 'f', 'Facebook 4 Business']], dtype=object)

# %%
dataframe1.describe().transpose()
# Out:
#      count    mean        std   min    25%   50%   75%   max
# Età    8.0  32.875  10.947113  19.0  26.25  30.0  39.5  53.0

# %%
iris = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", header=None)

# %%
iris.to_csv("Datasets/Risultati/iris_datasets_homew.csv", index=False, header=["Primo", "Secondo", "Terzo", "Quarto", "Quinto"])

# %%
iris.describe().transpose().to_csv("Datasets/Risultati/iris_descrizione_homew.csv")

# %%
print(pd.read_csv("Datasets/Risultati/iris_descrizione_homew.csv"))
# Out:
#    Unnamed: 0  count      mean       std  min  25%   50%  75%  max
# 0           0  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# 1           1  150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# 2           2  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# 3           3  150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
excel = pd.read_excel("/Users/raffaelesportiello/Downloads/(CONFIDENTIAL) Offerte Black Friday 2018 - Solo offerte lampo v2.xlsx", "Offerte Lampo (Tutte)")

# %%
excel.head()
# Out:
#                        BLACK FRIDAY  Unnamed: 1  \
# 0  Inserisci il tuo tracking ID >>>         NaN
# 1                               NaN         NaN
# 2                      BLACK FRIDAY         NaN
# 3                         CATEGORIA        ASIN
# 4                           Apparel  B00BRNDZ1U
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                      NOME PRODOTTO
# 4  UnsichtBra Set da 3 reggiseni benessere: Nero,...
#
#                             Unnamed: 3  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                     LINK NON TAGGATO
# 4  https://www.amazon.it/dp/B00BRNDZ1U
#
#                                       Unnamed: 4           Unnamed: 5  \
# ...

# %%
un_json = {
  "nome": "John",
  "eta": 30,
  "auto": "Fiat Punto"}

# %%
print(un_json)
# Out:
# {'nome': 'John', 'eta': 30, 'auto': 'Fiat Punto'}

# %%
type(un_json)
# Out:
# dict

# %%
tre_json = [
  {
    "nome": "John",
    "eta": 30,
    "auto": "Fiat Punto"
  },
  {
    "nome": "Pam",
    "eta": 35,
    "auto": "Opel Corsa"
  },
  {
    "nome": "Mark",
    "eta": 25,
    "auto": "Fiat Panda"
  }
]

# %%
print(tre_json)
# Out:
# [{'nome': 'John', 'eta': 30, 'auto': 'Fiat Punto'}, {'nome': 'Pam', 'eta': 35, 'auto': 'Opel Corsa'}, {'nome': 'Mark', 'eta': 25, 'auto': 'Fiat Panda'}]

# %%
type(tre_json[0])
# Out:
# dict

# %%
pd.DataFrame(tre_json)
# Out:
#          auto  eta  nome
# 0  Fiat Punto   30  John
# 1  Opel Corsa   35   Pam
# 2  Fiat Panda   25  Mark

# %%
type(pd.DataFrame(tre_json))
# Out:
# pandas.core.frame.DataFrame

# %%
json_annidati = [
  {
    "nome": "John",
    "eta": 30,
    "auto": {
              "lavoro": "Fiat Punto",
              "vacanza": "Peaugeot 206",
              "seconda": "Wolkswagen Golf"
             }
  },
  {
    "nome": "Pam",
    "eta": 35,
    "auto": "Opel Corsa"
  },
  {
    "nome": "Mark",
    "eta": 25,
    "auto": "Fiat Panda"
  }
]

# %%
print(json_annidati)
# Out:
# [{'nome': 'John', 'eta': 30, 'auto': {'lavoro': 'Fiat Punto', 'vacanza': 'Peaugeot 206', 'seconda': 'Wolkswagen Golf'}}, {'nome': 'Pam', 'eta': 35, 'auto': 'Opel Corsa'}, {'nome': 'Mark', 'eta': 25, 'auto': 'Fiat Panda'}]

# %%
pd.DataFrame(json_annidati)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4c21e4554bb3> in <module>
# ----> 1 pd.DataFrame(json_annidati)
#
# NameError: name 'pd' is not defined

# %%
import json

# %%
print(json.dumps(json_annidati))
# Out:
# [{"nome": "John", "eta": 30, "auto": {"lavoro": "Fiat Punto", "vacanza": "Peaugeot 206", "seconda": "Wolkswagen Golf"}}, {"nome": "Pam", "eta": 35, "auto": "Opel Corsa"}, {"nome": "Mark", "eta": 25, "auto": "Fiat Panda"}]

# %%
print(json.dumps(json_annidati, sort_keys=True, indent=2))
# Out:
# [
#   {
#     "auto": {
#       "lavoro": "Fiat Punto",
#       "seconda": "Wolkswagen Golf",
#       "vacanza": "Peaugeot 206"
#     },
#     "eta": 30,
#     "nome": "John"
#   },
#   {
#     "auto": "Opel Corsa",
#     "eta": 35,
#     "nome": "Pam"
#   },
#   {
#     "auto": "Fiat Panda",
#     "eta": 25,
#     "nome": "Mark"
#   }
# ]

# %%
json_file_homew = open("Datasets/risultati/json_file.json", "w")

# %%
to_print = json.dumps(json_annidati, sort_keys=True, indent=4)

# %%
json_file_homew.write(to_print)
# Out:
# 371

# %%
json_file_homew.close()

# %%
dizionario_dati = {"Nome": ["Giovanni", "Magda", "Elena", "Michele", "Anna", "Aldo", "Antonio", "Monica", "Anna"],
                   "Eta": [28, 27, 39, 32, 41, 19, 53, 24, 41],
                   "Genere": ["m", "f", "f", "m", "f", "m", "m", "f", "f"],
                   "Corso": ["Cyb", "BigD", "Cyb", "Scen", "F4B", "Cyb", "BigD", "F4B", "F4B"],
                   "Punteggio": [10, 9, 10, 9.5, 8, 9, 10, 8.5, 8]
                  }

# %%
type(dizionario_dati)
# Out:
# dict

# %%
print(dizionario_dati)
# Out:
# {'Nome': ['Giovanni', 'Magda', 'Elena', 'Michele', 'Anna', 'Aldo', 'Antonio', 'Monica', 'Anna'], 'Eta': [28, 27, 39, 32, 41, 19, 53, 24, 41], 'Genere': ['m', 'f', 'f', 'm', 'f', 'm', 'm', 'f', 'f'], 'Corso': ['Cyb', 'BigD', 'Cyb', 'Scen', 'F4B', 'Cyb', 'BigD', 'F4B', 'F4B'], 'Punteggio': [10, 9, 10, 9.5, 8, 9, 10, 8.5, 8]}

# %%
dizionario_dati["Eta"]
# Out:
# [28, 27, 39, 32, 41, 19, 53, 24, 41]

# %%
dataframe2 = pd.DataFrame(dizionario_dati)

# %%
dataframe2
# Out:
#        Nome  Eta Genere Corso  Punteggio
# 0  Giovanni   28      m   Cyb       10.0
# 1     Magda   27      f  BigD        9.0
# 2     Elena   39      f   Cyb       10.0
# 3   Michele   32      m  Scen        9.5
# 4      Anna   41      f   F4B        8.0
# 5      Aldo   19      m   Cyb        9.0
# 6   Antonio   53      m  BigD       10.0
# 7    Monica   24      f   F4B        8.5
# 8      Anna   41      f   F4B        8.0

# %%
dataframe2.describe().transpose()
# Out:
#            count       mean        std   min   25%   50%   75%   max
# Eta          9.0  33.777778  10.592188  19.0  27.0  32.0  41.0  53.0
# Punteggio    9.0   9.111111   0.820738   8.0   8.5   9.0  10.0  10.0

# %%
dataframe2.dtypes
# Out:
# Nome          object
# Eta            int64
# Genere        object
# Corso         object
# Punteggio    float64
# dtype: object

# %%
dataframe2.shape
# Out:
# (9, 5)

# %%
dataframe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
# Nome         9 non-null object
# Eta          9 non-null int64
# Genere       9 non-null object
# Corso        9 non-null object
# Punteggio    9 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 440.0+ bytes

# %%
dataframe2.set_index("Nome", inplace= True)

# %%
dataframe2.sort_values(by=["Corso", "Genere", "Eta"])
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Magda      27      f  BigD        9.0
# Antonio    53      m  BigD       10.0
# Elena      39      f   Cyb       10.0
# Aldo       19      m   Cyb        9.0
# Giovanni   28      m   Cyb       10.0
# Monica     24      f   F4B        8.5
# Anna       41      f   F4B        8.0
# Anna       41      f   F4B        8.0
# Michele    32      m  Scen        9.5

# %%
dataframe2
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Magda      27      f  BigD        9.0
# Elena      39      f   Cyb       10.0
# Michele    32      m  Scen        9.5
# Anna       41      f   F4B        8.0
# Aldo       19      m   Cyb        9.0
# Antonio    53      m  BigD       10.0
# Monica     24      f   F4B        8.5
# Anna       41      f   F4B        8.0

# %%
dataframe2.loc["Giovanni":"Michele","Genere":"Corso"]
# Out:
#          Genere Corso
# Nome
# Giovanni      m   Cyb
# Magda         f  BigD
# Elena         f   Cyb
# Michele       m  Scen

# %%
dataframe2.iloc[0:2, :]
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Magda      27      f  BigD        9.0

# %%
eta = dataframe2.loc[:, "Eta"]

# %%
eta
# Out:
# Nome
# Giovanni    28
# Magda       27
# Elena       39
# Michele     32
# Anna        41
# Aldo        19
# Antonio     53
# Monica      24
# Anna        41
# Name: Eta, dtype: int64

# %%
type(eta)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
np.random.rand(5, 5)
# Out:
# array([[1.48415061e-01, 6.61039176e-01, 6.38155140e-01, 3.71483770e-02,
#         3.36026115e-01],
#        [2.58434868e-01, 5.41451791e-01, 2.14763335e-01, 5.69719118e-01,
#         7.18285219e-01],
#        [5.70138980e-01, 7.36353038e-01, 2.13657117e-01, 2.76740385e-01,
#         3.54791664e-01],
#        [7.90075284e-02, 6.40400392e-02, 2.49187159e-04, 3.38531547e-01,
#         6.50087705e-01],
#        [6.64385924e-01, 9.35524140e-01, 4.52092039e-01, 7.06520869e-01,
#         6.74199500e-01]])

# %%
help(np.random.randn)
# Out:
# Help on built-in function randn:
#
# randn(...) method of mtrand.RandomState instance
#     randn(d0, d1, ..., dn)
#
#     Return a sample (or samples) from the "standard normal" distribution.
#
#     If positive, int_like or int-convertible arguments are provided,
#     `randn` generates an array of shape ``(d0, d1, ..., dn)``, filled
#     with random floats sampled from a univariate "normal" (Gaussian)
#     distribution of mean 0 and variance 1 (if any of the :math:`d_i` are
#     floats, they are first converted to integers by truncation). A single
#     float randomly sampled from the distribution is returned if no
#     argument is provided.
#
#     This is a convenience function.  If you want an interface that takes a
#     tuple as the first argument, use `numpy.random.standard_normal` instead.
#
#     Parameters
#     ----------
#     d0, d1, ..., dn : int, optional
#         The dimensions of the returned array, should be all positive.
# ...

# %%
breve_a = pd.DataFrame(np.random.rand(5, 5))

# %%
breve_a
# Out:
#           0         1         2         3         4
# 0  0.967010  0.775720  0.688885  0.045463  0.248679
# 1  0.643998  0.052236  0.107039  0.876669  0.561802
# 2  0.177500  0.215513  0.630221  0.075396  0.509854
# 3  0.189275  0.187484  0.133972  0.638579  0.414209
# 4  0.484714  0.493601  0.627194  0.665846  0.759632

# %%
breve_a.iloc[0:3]
# Out:
#           0         1         2         3         4
# 0  0.967010  0.775720  0.688885  0.045463  0.248679
# 1  0.643998  0.052236  0.107039  0.876669  0.561802
# 2  0.177500  0.215513  0.630221  0.075396  0.509854

# %%
breve_a.loc[0:3]
# Out:
#           0         1         2         3         4
# 0  0.967010  0.775720  0.688885  0.045463  0.248679
# 1  0.643998  0.052236  0.107039  0.876669  0.561802
# 2  0.177500  0.215513  0.630221  0.075396  0.509854
# 3  0.189275  0.187484  0.133972  0.638579  0.414209

# %%
breve_b = pd.DataFrame(np.random.rand(5, 5), index=[2, 4, 0, 1, 3])

# %%
breve_b
# Out:
#           0         1         2         3         4
# 2  0.595122  0.916548  0.337873  0.094643  0.093802
# 4  0.088896  0.134405  0.553057  0.924655  0.947610
# 0  0.736425  0.275380  0.676617  0.585856  0.852117
# 1  0.752243  0.369708  0.499667  0.247134  0.412598
# 3  0.186334  0.459881  0.016647  0.505204  0.515727

# %%
breve_b.iloc[0:3]
# Out:
#           0         1         2         3         4
# 2  0.595122  0.916548  0.337873  0.094643  0.093802
# 4  0.088896  0.134405  0.553057  0.924655  0.947610
# 0  0.736425  0.275380  0.676617  0.585856  0.852117

# %%
breve_b.loc[0:3]
# Out:
#           0         1         2         3         4
# 0  0.736425  0.275380  0.676617  0.585856  0.852117
# 1  0.752243  0.369708  0.499667  0.247134  0.412598
# 3  0.186334  0.459881  0.016647  0.505204  0.515727

# %%
breve_c = pd.DataFrame(np.random.rand(5, 5), index=["c", "e", "a", "d", "b"])

# %%
breve_c
# Out:
#           0         1         2         3         4
# c  0.616777  0.551298  0.563192  0.687458  0.866198
# e  0.425813  0.429452  0.706632  0.363154  0.685686
# a  0.518066  0.593895  0.403320  0.541151  0.437132
# d  0.260537  0.838200  0.095156  0.300650  0.520933
# b  0.489380  0.845914  0.536872  0.279104  0.918661

# %%
breve_c.iloc[0:3]
# Out:
#           0         1         2         3         4
# c  0.616777  0.551298  0.563192  0.687458  0.866198
# e  0.425813  0.429452  0.706632  0.363154  0.685686
# a  0.518066  0.593895  0.403320  0.541151  0.437132

# %%
breve_c.loc["a":"d"]
# Out:
#           0         1         2         3         4
# a  0.518066  0.593895  0.403320  0.541151  0.437132
# d  0.260537  0.838200  0.095156  0.300650  0.520933

# %%
condizione = dataframe2.Punteggio > 9
print(condizione)
# Out:
# Nome
# Giovanni     True
# Magda       False
# Elena        True
# Michele      True
# Anna        False
# Aldo        False
# Antonio      True
# Monica      False
# Anna        False
# Name: Punteggio, dtype: bool

# %%
dataframe2[condizione]
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Elena      39      f   Cyb       10.0
# Michele    32      m  Scen        9.5
# Antonio    53      m  BigD       10.0

# %%
dataframe2[dataframe2["Punteggio"] > 9]
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Elena      39      f   Cyb       10.0
# Michele    32      m  Scen        9.5
# Antonio    53      m  BigD       10.0

# %%
dataframe2["Punteggio"]
# Out:
# Nome
# Giovanni    10.0
# Magda        9.0
# Elena       10.0
# Michele      9.5
# Anna         8.0
# Aldo         9.0
# Antonio     10.0
# Monica       8.5
# Anna         8.0
# Name: Punteggio, dtype: float64

# %%
dataframe2[1:2]
# Out:
#        Eta Genere Corso  Punteggio
# Nome
# Magda   27      f  BigD        9.0

# %%
dataframe2.loc[dataframe2["Genere"] == "m"]
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Michele    32      m  Scen        9.5
# Aldo       19      m   Cyb        9.0
# Antonio    53      m  BigD       10.0

# %%
dataframe2[dataframe2["Genere"] == "m"]
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Michele    32      m  Scen        9.5
# Aldo       19      m   Cyb        9.0
# Antonio    53      m  BigD       10.0

# %%
dataframe2[ (dataframe2.Punteggio > 9) & (dataframe2.Genere == "f") ]
# Out:
#        Eta Genere Corso  Punteggio
# Nome
# Elena   39      f   Cyb       10.0

# %%
dataframe2.query("Punteggio > 9")
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Elena      39      f   Cyb       10.0
# Michele    32      m  Scen        9.5
# Antonio    53      m  BigD       10.0

# %%
dataframe2.query("Genere == 'm'")
# Out:
#           Eta Genere Corso  Punteggio
# Nome
# Giovanni   28      m   Cyb       10.0
# Michele    32      m  Scen        9.5
# Aldo       19      m   Cyb        9.0
# Antonio    53      m  BigD       10.0

# %%
dataframe2["New_Data"] = dataframe2.Punteggio / 10
print(dataframe2)
# Out:
#           Eta Genere Corso  Punteggio  New_Data
# Nome
# Giovanni   28      m   Cyb       10.0      1.00
# Magda      27      f  BigD        9.0      0.90
# Elena      39      f   Cyb       10.0      1.00
# Michele    32      m  Scen        9.5      0.95
# Anna       41      f   F4B        8.0      0.80
# Aldo       19      m   Cyb        9.0      0.90
# Antonio    53      m  BigD       10.0      1.00
# Monica     24      f   F4B        8.5      0.85
# Anna       41      f   F4B        8.0      0.80

# %%
gruppo1 = dataframe2.groupby("Genere")

# %%
gruppo1.groups
# Out:
# {'f': Index(['Magda', 'Elena', 'Anna', 'Monica', 'Anna'], dtype='object', name='Nome'),
#  'm': Index(['Giovanni', 'Michele', 'Aldo', 'Antonio'], dtype='object', name='Nome')}

# %%
dataframe2.loc[gruppo1.groups["f"]]
# Out:
#         Eta Genere Corso  Punteggio  New_Data
# Nome
# Magda    27      f  BigD        9.0      0.90
# Elena    39      f   Cyb       10.0      1.00
# Anna     41      f   F4B        8.0      0.80
# Anna     41      f   F4B        8.0      0.80
# Monica   24      f   F4B        8.5      0.85
# Anna     41      f   F4B        8.0      0.80
# Anna     41      f   F4B        8.0      0.80

# %%
gruppo2 = dataframe2.groupby("Corso")
gruppo2.groups
# Out:
# {'BigD': Index(['Magda', 'Antonio'], dtype='object', name='Nome'),
#  'Cyb': Index(['Giovanni', 'Elena', 'Aldo'], dtype='object', name='Nome'),
#  'F4B': Index(['Anna', 'Monica', 'Anna'], dtype='object', name='Nome'),
#  'Scen': Index(['Michele'], dtype='object', name='Nome')}

# %%
gruppo1.describe()
# Out:
#          Eta                                                  New_Data  \
#        count  mean        std   min    25%   50%    75%   max    count
# Genere
# f        5.0  34.4   8.234076  24.0  27.00  39.0  41.00  41.0      5.0
# m        4.0  33.0  14.399074  19.0  25.75  30.0  37.25  53.0      4.0
#
#                 ...            Punteggio                                     \
#           mean  ...   75%  max     count   mean       std  min    25%   50%
# Genere          ...
# f       0.8700  ...   0.9  1.0       5.0  8.700  0.836660  8.0  8.000  8.50
# m       0.9625  ...   1.0  1.0       4.0  9.625  0.478714  9.0  9.375  9.75
#
#
#          75%   max
# Genere
# f        9.0  10.0
# m       10.0  10.0
#
# [2 rows x 24 columns]

# %%
gruppo2.describe().transpose()
# Out:
# Corso                 BigD        Cyb        F4B   Scen
# Eta       count   2.000000   3.000000   3.000000   1.00
#           mean   40.000000  28.666667  35.333333  32.00
#           std    18.384776  10.016653   9.814955    NaN
#           min    27.000000  19.000000  24.000000  32.00
#           25%    33.500000  23.500000  32.500000  32.00
#           50%    40.000000  28.000000  41.000000  32.00
#           75%    46.500000  33.500000  41.000000  32.00
#           max    53.000000  39.000000  41.000000  32.00
# New_Data  count   2.000000   3.000000   3.000000   1.00
#           mean    0.950000   0.966667   0.816667   0.95
#           std     0.070711   0.057735   0.028868    NaN
#           min     0.900000   0.900000   0.800000   0.95
#           25%     0.925000   0.950000   0.800000   0.95
#           50%     0.950000   1.000000   0.800000   0.95
#           75%     0.975000   1.000000   0.825000   0.95
#           max     1.000000   1.000000   0.850000   0.95
# ...

# %%
dataframe2
# Out:
#           Eta Genere Corso  Punteggio  New_Data
# Nome
# Giovanni   28      m   Cyb       10.0      1.00
# Magda      27      f  BigD        9.0      0.90
# Elena      39      f   Cyb       10.0      1.00
# Michele    32      m  Scen        9.5      0.95
# Anna       41      f   F4B        8.0      0.80
# Aldo       19      m   Cyb        9.0      0.90
# Antonio    53      m  BigD       10.0      1.00
# Monica     24      f   F4B        8.5      0.85
# Anna       41      f   F4B        8.0      0.80

# %%
dataframe2.duplicated()
# Out:
# Nome
# Giovanni    False
# Magda       False
# Elena       False
# Michele     False
# Anna        False
# Aldo        False
# Antonio     False
# Monica      False
# Anna         True
# dtype: bool

# %%
dataframe3 = dataframe2.drop_duplicates()
print(dataframe3)
# Out:
#           Eta Genere Corso  Punteggio  New_Data
# Nome
# Giovanni   28      m   Cyb       10.0      1.00
# Magda      27      f  BigD        9.0      0.90
# Elena      39      f   Cyb       10.0      1.00
# Michele    32      m  Scen        9.5      0.95
# Anna       41      f   F4B        8.0      0.80
# Aldo       19      m   Cyb        9.0      0.90
# Antonio    53      m  BigD       10.0      1.00
# Monica     24      f   F4B        8.5      0.85

# %%
dataframe3.stack()
# Out:
# Nome
# Giovanni  Eta            28
#           Genere          m
#           Corso         Cyb
#           Punteggio      10
#           New_Data        1
# Magda     Eta            27
#           Genere          f
#           Corso        BigD
#           Punteggio       9
#           New_Data      0.9
# Elena     Eta            39
#           Genere          f
#           Corso         Cyb
#           Punteggio      10
#           New_Data        1
# Michele   Eta            32
#           Genere          m
#           Corso        Scen
#           Punteggio     9.5
#           New_Data     0.95
# Anna      Eta            41
#           Genere          f
#           Corso         F4B
#           Punteggio       8
#           New_Data      0.8
# Aldo      Eta            19
#           Genere          m
#           Corso         Cyb
#           Punteggio       9
#           New_Data      0.9
# Antonio   Eta            53
#           Genere          m
#           Corso        BigD
# ...

# %%
stack3 = dataframe3.stack()

# %%
stack3.unstack()
# Out:
#          Eta Genere Corso Punteggio New_Data
# Nome
# Giovanni  28      m   Cyb        10        1
# Magda     27      f  BigD         9      0.9
# Elena     39      f   Cyb        10        1
# Michele   32      m  Scen       9.5     0.95
# Anna      41      f   F4B         8      0.8
# Aldo      19      m   Cyb         9      0.9
# Antonio   53      m  BigD        10        1
# Monica    24      f   F4B       8.5     0.85

# %%
pd.melt(dataframe3)
# Out:
#      variable value
# 0         Eta    28
# 1         Eta    27
# 2         Eta    39
# 3         Eta    32
# 4         Eta    41
# 5         Eta    19
# 6         Eta    53
# 7         Eta    24
# 8      Genere     m
# 9      Genere     f
# 10     Genere     f
# 11     Genere     m
# 12     Genere     f
# 13     Genere     m
# 14     Genere     m
# 15     Genere     f
# 16      Corso   Cyb
# 17      Corso  BigD
# 18      Corso   Cyb
# 19      Corso  Scen
# 20      Corso   F4B
# 21      Corso   Cyb
# 22      Corso  BigD
# 23      Corso   F4B
# 24  Punteggio    10
# 25  Punteggio     9
# 26  Punteggio    10
# 27  Punteggio   9.5
# 28  Punteggio     8
# 29  Punteggio     9
# 30  Punteggio    10
# 31  Punteggio   8.5
# 32   New_Data     1
# 33   New_Data   0.9
# 34   New_Data     1
# 35   New_Data  0.95
# 36   New_Data   0.8
# 37   New_Data   0.9
# 38   New_Data     1
# 39   New_Data  0.85

# %%
help(pd.melt)
# Out:
# Help on function melt in module pandas.core.reshape.melt:
#
# melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None)
#     "Unpivots" a DataFrame from wide format to long format, optionally
#     leaving identifier variables set.
#
#     This function is useful to massage a DataFrame into a format where one
#     or more columns are identifier variables (`id_vars`), while all other
#     columns, considered measured variables (`value_vars`), are "unpivoted" to
#     the row axis, leaving just two non-identifier columns, 'variable' and
#     'value'.
#
#
#     Parameters
#     ----------
#     frame : DataFrame
#     id_vars : tuple, list, or ndarray, optional
#         Column(s) to use as identifier variables.
#     value_vars : tuple, list, or ndarray, optional
#         Column(s) to unpivot. If not specified, uses all columns that
#         are not set as `id_vars`.
#     var_name : scalar
# ...

# %%
dataframe2.sample(2)
# Out:
#           Eta Genere Corso  Punteggio  New_Data
# Nome
# Giovanni   28      m   Cyb       10.0       1.0
# Anna       41      f   F4B        8.0       0.8

# %%
dataframe2.sample(frac=0.2)
# Out:
#          Eta Genere Corso  Punteggio  New_Data
# Nome
# Michele   32      m  Scen        9.5      0.95
# Elena     39      f   Cyb       10.0      1.00

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot([5, 8, 1, 4, 4])
